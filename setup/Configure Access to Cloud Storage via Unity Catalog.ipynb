-- %%
%fs ls 'abfss://insurance@dbinsuranceextdl.dfs.core.windows.net/'

-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS db_insurance_ext_dl_insurance
    URL 'abfss://insurance@dbinsuranceextdl.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL db_insurance_project_sc)
    COMMENT 'External location for insurance data';

-- %%
%sql
SHOW CATALOGS;

-- %%
%sql
CREATE CATALOG IF NOT EXISTS safeinsure_prod
  MANAGED LOCATION 'abfss://insurance@dbinsuranceextdl.dfs.core.windows.net/'
  COMMENT 'Catalog for insurance data';

-- %%
%sql
USE CATALOG safeinsure_prod;

CREATE SCHEMA IF NOT EXISTS landing
MANAGED LOCATION 'abfss://insurance@dbinsuranceextdl.dfs.core.windows.net/';

CREATE SCHEMA IF NOT EXISTS bronze
MANAGED LOCATION 'abfss://insurance@dbinsuranceextdl.dfs.core.windows.net/';

CREATE SCHEMA IF NOT EXISTS silver
MANAGED LOCATION 'abfss://insurance@dbinsuranceextdl.dfs.core.windows.net/';

CREATE SCHEMA IF NOT EXISTS gold
MANAGED LOCATION 'abfss://insurance@dbinsuranceextdl.dfs.core.windows.net/';

-- %%
%sql
USE CATALOG safeinsure_prod;
USE SCHEMA landing;

CREATE EXTERNAL VOLUME IF NOT EXISTS operational_data
   LOCATION 'abfss://insurance@dbinsuranceextdl.dfs.core.windows.net/landing/operational_data';

-- %%
%fs ls /Volumes/safeinsure_prod/landing/operational_data
